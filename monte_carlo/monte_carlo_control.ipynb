# %%
import numpy as np

from environment import Easy21
from helpers import plot_value_function
from monte_carlo_control import epsilon_greedy_policy, monte_carlo_control

# %%
N_EPISODES = 1_000_000

# %%
env = Easy21()
Q = monte_carlo_control(env=env, policy=epsilon_greedy_policy, n_episodes=N_EPISODES)

plot_value_function(Q, state_action_value_function=True)
